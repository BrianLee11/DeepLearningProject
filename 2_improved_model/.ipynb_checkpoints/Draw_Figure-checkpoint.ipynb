# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Atten_GRU = pd.read_csv('data/attention24steps_preds_1080.csv')
Atten_GRU
# Out:
#      pred_attenGRU        true
# 0      -119.416850   -0.300026
# 1       -90.780556   -0.300026
# 2        68.778680   -0.300026
# 3       -37.450172   -0.300026
# 4       -16.384499   -0.300026
# ..             ...         ...
# 235     185.450650  271.350000
# 236     269.681580  213.330000
# 237     225.282240  196.610000
# 238     229.044510  194.230000
# 239     239.544250  163.810000
#
# [240 rows x 2 columns]

# %%
Atten_GRU_value = Atten_GRU.iloc[:,0].values
Atten_GRU_value
# Out:
# array([-1.19416850e+02, -9.07805560e+01,  6.87786800e+01, -3.74501720e+01,
#        -1.63844990e+01,  7.14269600e+01,  2.02939070e+01, -3.94838940e+01,
#        -3.04013140e+01,  1.59505410e+00, -2.33795850e+01, -4.16867880e+00,
#         3.68265840e-02,  5.98265800e+00,  3.30802400e-01, -1.18276150e+01,
#         2.75078660e+01, -2.14316480e+01, -1.91184770e+01,  2.50840680e+01,
#         3.64327300e+01,  3.77613140e+01, -2.71245800e+01, -3.73335040e+01,
#         5.74059680e+01, -2.73777850e+01, -8.09745100e+00, -3.88539500e+01,
#        -5.83802260e+01,  8.93959700e+00, -2.41803970e+01,  3.81086960e+01,
#         3.67934370e+00, -3.58253250e+01,  2.35126880e+01, -7.85530570e-01,
#         2.08174670e+01,  7.04308270e+00, -6.71906330e+00,  4.73056260e+01,
#         7.02565700e+01, -8.36509000e+00, -4.48252940e+01, -1.28131800e+01,
#         2.55698780e+01, -3.44775160e+01, -3.42866300e+01,  9.50542400e+00,
# ...

# %%
true_value = Atten_GRU.iloc[:,1].values
true_value
# Out:
# array([-3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
#        -3.0002645e-01, -3.0002645e-01, -3.0002645e-01, -3.0002645e-01,
# ...

# %%
LSTM = pd.read_csv('data/LSTM24steps_preds1080.csv')
LSTM
# Out:
#        LSTMpred        true
# 0    -34.139490    0.000000
# 1     15.728619   -0.299995
# 2     50.572590   -0.299995
# 3     81.141260   -0.299995
# 4    104.284360   -0.299995
# ..          ...         ...
# 235  112.030150  271.350000
# 236  116.338250  213.329990
# 237  111.649610  196.609990
# 238  114.510810  194.230000
# 239  113.852720  163.810000
#
# [240 rows x 2 columns]

# %%
LSTM_value = LSTM.iloc[:,0].values
LSTM_value
# Out:
# array([ -34.13949 ,   15.728619,   50.57259 ,   81.14126 ,  104.28436 ,
#         118.36516 ,  119.541695,  121.92561 ,  127.0963  ,  124.87132 ,
#         119.71681 ,  107.27909 ,  116.57718 ,  106.48331 ,  122.53667 ,
#         105.56725 ,  111.32539 ,  113.50499 ,  115.87445 ,  113.44469 ,
#         106.66179 ,  105.17012 ,  116.46207 ,  111.64859 ,    8.19133 ,
#          42.21517 ,   53.957623,   87.03195 ,  113.86281 ,  115.811356,
#         125.84642 ,  114.34599 ,  127.81921 ,  120.28735 ,  122.37589 ,
#         111.705376,  116.09694 ,  105.61766 ,  117.453224,  109.682785,
#         108.86457 ,  106.105316,  112.51756 ,  100.20209 ,  112.12384 ,
#         115.55173 ,  102.87106 ,  105.26547 ,   22.085003,   59.392273,
#          81.98478 ,   93.82414 ,  109.86015 ,  116.56192 ,  123.324554,
#         120.185104,  119.67673 ,  113.903656,  118.48137 ,  117.715904,
#         108.57682 ,  116.2659  ,  109.41969 ,  111.580666,  121.518486,
# ...

# %%
RNN = pd.read_csv('data/EnDecoderGRU24steps_preds.csv')
RNN
# Out:
#      pred_Encoder_GRU        true
# 0            71.55085   -0.300026
# 1           163.94177   -0.300026
# 2            91.81031   -0.300026
# 3            86.94120   -0.300026
# 4           107.74906   -0.300026
# ..                ...         ...
# 235         294.61002  271.350000
# 236         144.01668  213.330000
# 237         205.89493  196.610000
# 238         259.61133  194.230000
# 239         217.66974  163.810000
#
# [240 rows x 2 columns]

# %%
RNN_value = RNN.iloc[:,0].values
RNN_value
# Out:
# array([ 7.15508500e+01,  1.63941770e+02,  9.18103100e+01,  8.69412000e+01,
#         1.07749060e+02,  2.23266940e+02,  1.65732390e+02,  8.94372800e+01,
#         1.48646150e+01,  1.08963005e+02,  1.08174280e+02,  1.65167190e+02,
#         7.08703500e+01,  1.08279015e+02,  1.05739265e+02,  7.20019450e+01,
#         1.08999794e+02,  1.26049540e+02,  1.69044950e+02,  8.72335900e+01,
#         6.69340600e+01,  1.47744450e+02,  1.17111930e+02,  1.05254650e+02,
#         2.86940550e+02,  2.11529540e+02,  3.17202800e+02,  1.68553390e+02,
#         2.12591230e+02,  3.33917080e+02,  2.63373020e+02,  5.22983000e+01,
#         1.11790565e+02,  2.49121020e+02,  2.01154680e+02,  3.20772030e+02,
#         2.67423700e+02,  2.64983920e+02,  2.24791400e+02,  2.31601460e+02,
#         1.28693590e+02,  1.45499470e+02,  1.50214420e+02,  2.67331670e+02,
#         2.55450840e+02,  3.94228130e+01,  2.03870200e+02,  3.10063870e+02,
# ...

# %%
plt.figure(1)
fs = (10,6)
plt.figure(figsize=fs,dpi=120)
xs = np.arange(len(true_value[120:180]))
#xs = np.arange(288*2)
    
plt.title('24 time steps forecasting')
plt.xlabel('Steps')
plt.ylabel('Wind Power(kw)')
plt.plot(xs, Atten_GRU_value[120:180], '-.g', linewidth = 1.0, label = 'Our_Mode')
plt.plot(xs, true_value[120:180], '-r', linewidth = 0.8, label = 'True_Value')

plt.plot(xs, RNN_value[120:180], 'hotpink', linestyle='-.',linewidth = 1.0, label = 'EncoderGRU')

plt.plot(xs, LSTM_value[120:180], color='cyan', linestyle='-.',linewidth = 1.0, label = 'LSTM')

plt.grid(linestyle='-.', linewidth = 1)
plt.legend()
#plt.savefig('Save_figure/24steps_comparison.png', dpi=1600)
plt.show()

# %%
def mse(pred, gt):
    """
    Desc:
        Mean Square Error
    Args:
        pred:
        gt: ground truth vector
    Returns:
        MSE value
    """
    _mse = 0.
    if len(pred) > 0 and len(gt) > 0:
        _mse = np.mean((pred - gt) ** 2)
    return _mse


def rmse(pred, gt):
    """
    Desc:
        Root Mean Square Error
    Args:
        pred:
        gt: ground truth vector
    Returns:
        RMSE value
    """
    return np.sqrt(mse(pred, gt))

def mape(pred, gt):
    """
    Desc:
        Mean Absolute Percentage Error
    Args:
        pred:
        gt: ground truth vector
    Returns:
        MAPE value
    """
    _mape = 0.
    if len(pred) > 0 and len(gt) > 0:
        _mape = np.mean(np.abs((pred - gt) / gt))
    return _mape

def mspe(pred, gt):
    """
    Desc:
        Mean Square Percentage Error
    Args:
        pred:
        gt: ground truth vector
    Returns:
        MSPE value
    """
    return np.mean(np.square((pred - gt) / gt)) if len(pred) > 0 and len(gt) > 0 else 0

# %%
mape_attGRU = mape(Atten_GRU_value[100:200], true_value[100:200])
mape_attGRU
# Out:
# 0.2728747556346634

# %%
rmse_attGRU = rmse(Atten_GRU_value[100:200], true_value[100:200])
rmse_attGRU
# Out:
# 264.3510185721042

# %%
mape_EncoderGRU_value = mape(EncoderGRU_value[100:200], true_value[100:200])
mape_EncoderGRU_value
# Out:
# 0.6248151960156493

# %%
rmse_EncoderGRU_value = rmse(EncoderGRU_value[100:200], true_value[100:200])
rmse_EncoderGRU_value
# Out:
# 447.3998000618691

# %%
mape_LSTM_value = mape(LSTM_value[100:200], true_value[100:200])
mape_LSTM_value
# Out:
# 0.6776844666919791

# %%
rmse_LSTM_value = rmse(LSTM_value[100:200], true_value[100:200])
rmse_LSTM_value
# Out:
# 501.75480818892026
